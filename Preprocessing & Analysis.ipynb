# %% [markdown]
# ### Importing Liberaries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns #For statistics

# %%
data = pd.read_excel("datasets/StartupExpansion.xlsx")

# %%
data.head()
# Out:
#    Store ID           City       State Sales Region New Expansion  \
# 0         1         Peoria     Arizona     Region 2           Old
# 1         2        Midland       Texas     Region 2           Old
# 2         3        Spokane  Washington     Region 2           Old
# 3         4         Denton       Texas     Region 2           Old
# 4         5  Overland Park      Kansas     Region 2           Old
#
#    Marketing Spend  Revenue
# 0             2601    48610
# 1             2727    45689
# 2             2768    49554
# 3             2759    38284
# 4             2869    59887

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Store ID         150 non-null    int64
#  1   City             150 non-null    object
#  2   State            150 non-null    object
#  3   Sales Region     150 non-null    object
#  4   New Expansion    150 non-null    object
#  5   Marketing Spend  150 non-null    int64
#  6   Revenue          150 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 8.3+ KB

# %%
data.describe()
# Out:
#          Store ID  Marketing Spend       Revenue
# count  150.000000       150.000000    150.000000
# mean    75.500000      2893.146667  39301.433333
# std     43.445368       367.862817  15465.753977
# min      1.000000      1811.000000  15562.000000
# 25%     38.250000      2662.250000  21113.500000
# 50%     75.500000      2898.000000  42993.000000
# 75%    112.750000      3111.500000  51145.500000
# max    150.000000      3984.000000  68828.000000

# %%
data.describe().round(1)
# Out:
#        Store ID  Marketing Spend  Revenue
# count     150.0            150.0    150.0
# mean       75.5           2893.1  39301.4
# std        43.4            367.9  15465.8
# min         1.0           1811.0  15562.0
# 25%        38.2           2662.2  21113.5
# 50%        75.5           2898.0  42993.0
# 75%       112.8           3111.5  51145.5
# max       150.0           3984.0  68828.0

# %%
data[['Marketing Spend' , 'Revenue']].describe().round(2)
# Out:
#        Marketing Spend   Revenue
# count           150.00    150.00
# mean           2893.15  39301.43
# std             367.86  15465.75
# min            1811.00  15562.00
# 25%            2662.25  21113.50
# 50%            2898.00  42993.00
# 75%            3111.50  51145.50
# max            3984.00  68828.00

# %%
data['City'].value_counts()
# Out:
# Rochester        2
# Killeen          1
# Wichita Falls    1
# Naperville       1
# Clovis           1
#                 ..
# Akron            1
# Fullerton        1
# Manchester       1
# Everett          1
# Thousand Oaks    1
# Name: City, Length: 149, dtype: int64

# %%
data['State'].unique()
# Out:
# array(['Arizona', 'Texas', 'Washington', 'Kansas', 'New York', 'Alabama',
#        'California', 'Massachusetts', 'New Mexico', 'Mississippi',
#        'Oregon', 'Florida', 'Oklahoma', 'New Jersey', 'Utah', 'Colorado',
#        'Michigan', 'South Carolina', 'Virginia', 'Ohio', 'New Hampshire',
#        'Connecticut', 'Iowa', 'Arkansas', 'Tennessee', 'North Carolina',
#        'Georgia', 'Illinois', 'Montana', 'Indiana', 'South Dakota',
#        'Louisiana', 'Minnesota', 'Wisconsin', 'Rhode Island'],
#       dtype=object)

# %%
data['State'].nunique()
# Out:
# 35

# %%
data['State'].value_counts()
# Out:
# California        40
# Texas             17
# Florida           12
# Washington         7
# Colorado           5
# Illinois           5
# Georgia            4
# Alabama            4
# Connecticut        4
# New Jersey         4
# Arizona            3
# Tennessee          3
# Iowa               3
# Michigan           3
# South Carolina     3
# Utah               3
# Massachusetts      3
# Kansas             3
# New York           3
# Louisiana          2
# North Carolina     2
# Ohio               2
# Virginia           2
# Oregon             2
# Mississippi        1
# New Mexico         1
# Arkansas           1
# New Hampshire      1
# Oklahoma           1
# Montana            1
# Indiana            1
# South Dakota       1
# Minnesota          1
# Wisconsin          1
# Rhode Island       1
# Name: State, dtype: int64

# %%
data['New Expansion'].value_counts().Old
# Out:
# 140

# %%
data[['Revenue' , 'New Expansion']].value_counts()
# Out:
# Revenue  New Expansion
# 15562    Old              1
# 48254    Old              1
# 48610    Old              1
# 48796    Old              1
# 48933    Old              1
#                          ..
# 29008    Old              1
# 33647    Old              1
# 34603    New              1
# 34829    Old              1
# 68828    Old              1
# Length: 150, dtype: int64

# %%
data.isna().sum()
# Out:
# Store ID           0
# City               0
# State              0
# Sales Region       0
# New Expansion      0
# Marketing Spend    0
# Revenue            0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.drop_duplicates()
# Out:
#      Store ID             City       State Sales Region New Expansion  \
# 0           1           Peoria     Arizona     Region 2           Old
# 1           2          Midland       Texas     Region 2           Old
# 2           3          Spokane  Washington     Region 2           Old
# 3           4           Denton       Texas     Region 2           Old
# 4           5    Overland Park      Kansas     Region 2           Old
# ..        ...              ...         ...          ...           ...
# 145       146         Paterson  New Jersey     Region 1           New
# 146       147      Brownsville       Texas     Region 2           New
# 147       148         Rockford    Illinois     Region 1           New
# 148       149  College Station       Texas     Region 2           New
# 149       150    Thousand Oaks  California     Region 2           New
#
#      Marketing Spend  Revenue  Profit   ROI%     ROI
# 0               2601    48610   46009  17.69  1769.0
# ...

# %%
data.dropna()
# Out:
#      Store ID             City       State Sales Region New Expansion  \
# 0           1           Peoria     Arizona     Region 2           Old
# 1           2          Midland       Texas     Region 2           Old
# 2           3          Spokane  Washington     Region 2           Old
# 3           4           Denton       Texas     Region 2           Old
# 4           5    Overland Park      Kansas     Region 2           Old
# ..        ...              ...         ...          ...           ...
# 145       146         Paterson  New Jersey     Region 1           New
# 146       147      Brownsville       Texas     Region 2           New
# 147       148         Rockford    Illinois     Region 1           New
# 148       149  College Station       Texas     Region 2           New
# 149       150    Thousand Oaks  California     Region 2           New
#
#      Marketing Spend  Revenue  Profit   ROI%     ROI
# 0               2601    48610   46009  17.69  1769.0
# ...

# %% [markdown]
# ### Exploratory data analysis

# %%
data.sample(5)
# Out:
#      Store ID             City       State Sales Region New Expansion  \
# 79         80       Costa Mesa  California     Region 2           Old
# 62         63         Richmond  California     Region 2           Old
# 12         13       Las Cruces  New Mexico     Region 2           Old
# 129       130    Pompano Beach     Florida     Region 1           Old
# 81         82  Fort Lauderdale     Florida     Region 1           Old
#
#      Marketing Spend  Revenue
# 79              2275    41361
# 62              3924    19448
# 12              2895    19888
# 129             2608    21603
# 81              3217    54768

# %%
data['Sales Region'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
data['New Expansion'].value_counts().plot(kind="pie" , labels = ['Old','New'] )
# Out:
# <AxesSubplot: ylabel='New Expansion'>

# %%
data.groupby('New Expansion')

# %%
data[data['New Expansion']=='New'].Revenue.mean()
# Out:
# 45809.4

# %%
data[data['New Expansion']=='Old'].Revenue.mean()
# Out:
# 38836.578571428574

# %%
data[data['New Expansion']=='Old'][['Revenue' , 'City']]
# Out:
#      Revenue           City
# 0      48610         Peoria
# 1      45689        Midland
# 2      49554        Spokane
# 3      38284         Denton
# 4      59887  Overland Park
# ..       ...            ...
# 135    19426      San Mateo
# 136    47262         Warren
# 137    19703        Norwalk
# 138    40255      Lafayette
# 139    62337     Providence
#
# [140 rows x 2 columns]

# %%
data [data['New Expansion']=='Old'].groupby('State').sum()['Revenue'].nlargest(10)
# Out:
# State
# California     1362468
# Texas           554964
# Florida         479023
# Washington      298013
# Alabama         221025
# New York        160046
# Connecticut     158511
# Georgia         157656
# Colorado        156495
# Michigan        147759
# Name: Revenue, dtype: int64

# %%
data[data['New Expansion']=='New'].groupby('State').sum()['Revenue'].nlargest(10)
# Out:
# State
# California    141883
# Illinois       91692
# Texas          85605
# Tennessee      55357
# Arizona        48954
# New Jersey     34603
# Name: Revenue, dtype: int64

# %%
data['Profit'] = data['Revenue'] - data['Marketing Spend']

# %%
data
# Out:
#      Store ID             City       State Sales Region New Expansion  \
# 0           1           Peoria     Arizona     Region 2           Old
# 1           2          Midland       Texas     Region 2           Old
# 2           3          Spokane  Washington     Region 2           Old
# 3           4           Denton       Texas     Region 2           Old
# 4           5    Overland Park      Kansas     Region 2           Old
# ..        ...              ...         ...          ...           ...
# 145       146         Paterson  New Jersey     Region 1           New
# 146       147      Brownsville       Texas     Region 2           New
# 147       148         Rockford    Illinois     Region 1           New
# 148       149  College Station       Texas     Region 2           New
# 149       150    Thousand Oaks  California     Region 2           New
#
#      Marketing Spend  Revenue  Profit
# 0               2601    48610   46009
# 1               2727    45689   42962
# ...

# %%
data['ROI%'] =round( data['Profit'] / data['Marketing Spend'] , 2)

# %%
data['ROI'] = data['ROI%']*100

# %%
data
# Out:
#      Store ID             City       State Sales Region New Expansion  \
# 0           1           Peoria     Arizona     Region 2           Old
# 1           2          Midland       Texas     Region 2           Old
# 2           3          Spokane  Washington     Region 2           Old
# 3           4           Denton       Texas     Region 2           Old
# 4           5    Overland Park      Kansas     Region 2           Old
# ..        ...              ...         ...          ...           ...
# 145       146         Paterson  New Jersey     Region 1           New
# 146       147      Brownsville       Texas     Region 2           New
# 147       148         Rockford    Illinois     Region 1           New
# 148       149  College Station       Texas     Region 2           New
# 149       150    Thousand Oaks  California     Region 2           New
#
#      Marketing Spend  Revenue  Profit   ROI%     ROI
# 0               2601    48610   46009  17.69  1769.0
# ...

# %%
data[data['New Expansion']=='Old'].groupby('City').sum()['Revenue' ]
# Out:
# City
# Akron               50364
# Amarillo            56089
# Antioch             19569
# Augusta             47482
# Aurora              50650
#                     ...
# West Valley City    49609
# Wichita Falls       15735
# Woodbridge          19811
# Worcester           59840
# Yonkers             53827
# Name: Revenue, Length: 139, dtype: int64

# %%
data.to_csv('startups-expansion-modified.csv')
